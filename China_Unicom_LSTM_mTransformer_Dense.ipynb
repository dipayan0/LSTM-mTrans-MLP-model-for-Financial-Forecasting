# %%
# Import Necessary Libraries

import os
import warnings
warnings.filterwarnings('ignore')
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from pmdarima.arima import auto_arima

from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
import numpy as np

from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import yfinance as yf
#from nsepy import get_history

# %%
#sbin=pd.read_csv('bitcoin.csv')
sbin=pd.read_csv('600050.csv')

df_close=sbin['Close'].reset_index()

print(sbin.head(-10))
print(sbin.info())
# Out:
#             Date  Open  High   Low  Close  Adj Close      Volume
# 0     2002-10-09  3.05  3.15  2.86   2.87   2.167680  1304738321
# 1     2002-10-10  2.83  2.89  2.79   2.83   2.137469   202927101
# 2     2002-10-11  2.85  2.96  2.83   2.94   2.220551   173135913
# 3     2002-10-14  2.96  3.02  2.94   3.01   2.273421   178761083
# 4     2002-10-15  3.01  3.01  2.96   2.98   2.250762    90834152
# ...          ...   ...   ...   ...    ...        ...         ...
# 5361  2024-08-06  4.67  4.70  4.53   4.59   4.590000   189249971
# 5362  2024-08-07  4.59  4.64  4.57   4.57   4.570000    96292592
# 5363  2024-08-08  4.56  4.62  4.55   4.59   4.590000    85446257
# 5364  2024-08-09  4.59  4.62  4.52   4.52   4.520000   121107059
# 5365  2024-08-12  4.53  4.53  4.44   4.46   4.460000   102663976
#
# [5366 rows x 7 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5376 entries, 0 to 5375
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5376 non-null   object
#  1   Open       5376 non-null   float64
#  2   High       5376 non-null   float64
#  3   Low        5376 non-null   float64
#  4   Close      5376 non-null   float64
#  5   Adj Close  5376 non-null   float64
#  6   Volume     5376 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 294.1+ KB
# None

# %%
plt.plot(sbin['Close'])
plt.show()

# %%
sbin['Close'] = pd.to_numeric(sbin['Close'])

#sbin['Open'] = pd.to_numeric(sbin['Open'], errors='coerce')
#sbin['High'] = pd.to_numeric(sbin['High'], errors='coerce')

sbin['Date'] = pd.to_datetime(sbin['Date'], errors='coerce')
print(sbin.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5376 entries, 0 to 5375
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5376 non-null   datetime64[ns]
#  1   Open       5376 non-null   float64
#  2   High       5376 non-null   float64
#  3   Low        5376 non-null   float64
#  4   Close      5376 non-null   float64
#  5   Adj Close  5376 non-null   float64
#  6   Volume     5376 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 294.1 KB
# None

# %%
# Plotting Time data

plt.figure(figsize=(10,6))
plt.grid(True)

plt.xlabel('Dates')
plt.ylabel('Close Prices')
plt.plot(sbin['Date'],sbin['Close'])
plt.title('SBIN closing price')
plt.show()

# %%
# No need for this case

# Re-arranging Index

#df1=sbin.iloc[::-1]
#print(df1.head())
#print(df1.shape)
#df2=pd.DataFrame(data=df1.values, columns=df1.columns, index=range(0,df1.shape[0]))
#print(df2.head())

# %%
# Scatter Plot of re-arranged indexed dataframe
df1=sbin.iloc[::-1]
df2=sbin

plt.figure(figsize=(10,6))
df_close = df2['Close']
df_close.plot(style='k.')
plt.title('Scatter plot of closing price')
plt.show()

# %%
print(df1.describe())
plt.plot(df1.Close)
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5376.000000  5376.000000  5376.000000  5376.000000  5376.000000
# mean      4.907310     4.987243     4.834637     4.912500     4.201987
# std       1.719753     1.769704     1.672915     1.722589     1.490159
# min       2.200000     2.230000     2.190000     2.200000     1.746935
# 25%       3.490000     3.540000     3.460000     3.497500     3.000260
# 50%       4.800000     4.865000     4.720000     4.800000     4.210249
# 75%       5.800000     5.900000     5.710000     5.810000     5.070478
# max      13.130000    13.500000    12.850000    13.080000    10.507858
#
#              Volume
# count  5.376000e+03
# mean   1.606155e+08
# std    1.700052e+08
# min    0.000000e+00
# 25%    6.104405e+07
# 50%    1.051289e+08
# 75%    1.913926e+08
# max    1.721668e+09

# %%
# Histogram of Closing Price of BitCoin

plt.figure(figsize=(10,6))
#df_close = sbin.Close[sbin.Close.index[::-1]].values
df_close.plot(style='k.',kind='hist')
plt.title('Hisogram of Stock Price China Unicom (600050)')
plt.xlabel('Price (CNY)')
plt.show()

# %% [markdown]
# Neural Network

# %%
# import libraries

import math
import pandas as pd
import pandas_datareader as web
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Conv1D, MaxPooling1D, Flatten
import matplotlib.pyplot as plt
import os
from pandas_datareader import data as pdr
import yfinance as yf

plt.style.use('fivethirtyeight')

# %%
# Selecting data points as the paper

#idxs=df2.index[df2['Date']=='2011-01-06'].values
idxs=df2.index[df2['Date']=='2002-10-09'].values

#print(idxs, df2.Close[idxs])
#print(idxs)
idxn=df2.index[df2['Date']=='2021-03-17'].values
#print('ddd',idxn)

dataT=df2.filter(['Close'])  # Total dataset

data=dataT[int(idxs):int(idxn)]  # Dataset equal to the paper

print(idxn)
dataset=data.values
#print('dataset = ', dataset)
# Out:
# [4538]

# %%
plt.xlabel('Dates')
plt.ylabel('Close Prices')
plt.plot(dataset)
plt.title('SBIN closing price')
plt.show()

# %%
# Scale the data

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(dataset)

#print(scaled_data)

# %%
# Create the training dataset


training_data_len=math.ceil(len(dataset)* 0.8)
print(training_data_len)



train_data=scaled_data[0:training_data_len,:]

x_train=[]
y_train=[]

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i,0])
    #if i <=61:
        #print(x_train)
        #print(y_train)

        
# create Test dataset


        
test_data=scaled_data[training_data_len -60: , :]

x_test=[]
y_test= dataset [training_data_len:, :]



for i in range (60, len(test_data)):
    x_test.append(test_data[i-60:i,0])
# Out:
# 3631

# %%
print(scaled_data)
plt.plot(train_data)
plt.plot(test_data)
# Out:
# [[0.06158088]
#  [0.05790441]
#  [0.06801471]
#  ...
#  [0.20955882]
#  [0.21507353]
#  [0.21783088]]

# %%
#convert x_train and y_train to numpy array


x_train, y_train = np.array(x_train), np.array(y_train)
print(x_train.shape)


# convert data to numpy array 

x_test= np.array(x_test)
print(x_test.shape)
# Out:
# (3571, 60)
# (907, 60)

# %%
#reshape the data

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1],1))
print(x_train.shape)


x_test=np.reshape(x_test,(x_test.shape[0], x_test.shape[1],1))
print(x_test.shape)
# Out:
# (3571, 60, 1)
# (907, 60, 1)

# %% [markdown]
# # Model Create and train

# %%
# LSTM-Attention-Dense


import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LayerNormalization, MultiHeadAttention, Dropout, GlobalAveragePooling1D, Reshape
from sklearn.metrics import mean_squared_error
import math
import matplotlib.pyplot as plt



# Transformer Block
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = Dropout(dropout)(x)
    res = x + inputs

    x = LayerNormalization(epsilon=1e-6)(res)
    x = Dense(ff_dim, activation="relu")(x)
    x = Dropout(dropout)(x)
    x = Dense(inputs.shape[-1])(x)
    return x + res

# Model Definition
inputs = Input(shape=(x_train.shape[1], x_train.shape[2]))
x = LSTM(30, return_sequences = True, input_shape = (60,1))(inputs)
x = LSTM(20, return_sequences = False)(x)
x = Reshape((20,1))(x)
x = Dropout(0.1)(x)
#x = transformer_encoder(x, head_size=120, num_heads=5, ff_dim=5, dropout=0.15)
x = transformer_encoder(x, head_size=15, num_heads=4, ff_dim=4, dropout=0.15)

x = GlobalAveragePooling1D(data_format='channels_first')(x)
x = Dropout(0.1)(x)
#x = Dense(50, activation="relu")(x)
#x = Dropout(0.1)(x)

x = Dense(30, activation="relu")(x)
outputs = Dense(1, activation="linear")(x)

model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer="adam", loss="mean_squared_error")

# Model Summary
model.summary()


model.fit(x_train, y_train,  epochs=12, batch_size=1, verbose=1)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 60, 1)]              0         []
#
#  lstm (LSTM)                 (None, 60, 30)               3840      ['input_1[0][0]']
#
#  lstm_1 (LSTM)               (None, 20)                   4080      ['lstm[0][0]']
#
#  reshape (Reshape)           (None, 20, 1)                0         ['lstm_1[0][0]']
#
#  dropout (Dropout)           (None, 20, 1)                0         ['reshape[0][0]']
#
#  layer_normalization (Layer  (None, 20, 1)                2         ['dropout[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 20, 1)                421       ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  dropout_1 (Dropout)         (None, 20, 1)                0         ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 20, 1)                0         ['dropout_1[0][0]',
#  Lambda)                                                             'dropout[0][0]']
#
#  layer_normalization_1 (Lay  (None, 20, 1)                2         ['tf.__operators__.add[0][0]']
#  erNormalization)
#
#  dense (Dense)               (None, 20, 4)                8         ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 20, 4)                0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 20, 1)                5         ['dropout_2[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 20, 1)                0         ['dense_1[0][0]',
#  OpLambda)                                                           'tf.__operators__.add[0][0]']
#
#  global_average_pooling1d (  (None, 20)                   0         ['tf.__operators__.add_1[0][0]
#  GlobalAveragePooling1D)                                            ']
#
#  dropout_3 (Dropout)         (None, 20)                   0         ['global_average_pooling1d[0][
#                                                                     0]']
#
#  dense_2 (Dense)             (None, 30)                   630       ['dropout_3[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    31        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 9019 (35.23 KB)
# Trainable params: 9019 (35.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/12
# 3571/3571 [==============================] - 41s 11ms/step - loss: 0.0022
# Epoch 2/12
# 3571/3571 [==============================] - 38s 11ms/step - loss: 0.0013
# Epoch 3/12
# 3571/3571 [==============================] - 37s 10ms/step - loss: 9.9655e-04
# Epoch 4/12
# 3571/3571 [==============================] - 39s 11ms/step - loss: 9.0968e-04
# Epoch 5/12
# 3571/3571 [==============================] - 39s 11ms/step - loss: 7.6019e-04
# Epoch 6/12
# 3571/3571 [==============================] - 40s 11ms/step - loss: 7.0251e-04
# Epoch 7/12
# 3571/3571 [==============================] - 42s 12ms/step - loss: 7.1147e-04
# Epoch 8/12
# 3571/3571 [==============================] - 42s 12ms/step - loss: 6.1254e-04
# Epoch 9/12
# 3571/3571 [==============================] - 42s 12ms/step - loss: 5.3478e-04
# Epoch 10/12
# 3571/3571 [==============================] - 42s 12ms/step - loss: 5.5934e-04
# Epoch 11/12
# 3571/3571 [==============================] - 47s 13ms/step - loss: 5.0102e-04
# Epoch 12/12
# 3571/3571 [==============================] - 43s 12ms/step - loss: 4.9679e-04

# %%
## Only Dense Model 


import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LayerNormalization, MultiHeadAttention, Dropout, GlobalAveragePooling1D, Reshape
from sklearn.metrics import mean_squared_error
import math
import matplotlib.pyplot as plt


model=Sequential()
model.add(Dense(80, input_shape = (60,1)))
model.add(Flatten())
model.add(Dense(80, activation='relu'))
model.add(Dense(80, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='relu'))

model.summary()
#from sklearn.metrics import classification_report, confusion_matrix

model.compile(optimizer = 'adam', loss='mean_squared_error', metrics=['mse'])

# %%
# More Training (if Required)

model.fit(x_train, y_train, batch_size=1, epochs=10, workers=16)
# Out:
# Epoch 1/10
# 3571/3571 [==============================] - 41s 12ms/step - loss: 5.0879e-04
# Epoch 2/10
# 3571/3571 [==============================] - 43s 12ms/step - loss: 5.0140e-04
# Epoch 3/10
# 3571/3571 [==============================] - 42s 12ms/step - loss: 4.7118e-04
# Epoch 4/10
# 3571/3571 [==============================] - 40s 11ms/step - loss: 4.3374e-04
# Epoch 5/10
# 3571/3571 [==============================] - 38s 11ms/step - loss: 5.0276e-04
# Epoch 6/10
# 3571/3571 [==============================] - 38s 11ms/step - loss: 4.7309e-04
# Epoch 7/10
# 3571/3571 [==============================] - 38s 11ms/step - loss: 4.3346e-04
# Epoch 8/10
# 3571/3571 [==============================] - 38s 11ms/step - loss: 4.5252e-04
# Epoch 9/10
# 3571/3571 [==============================] - 38s 11ms/step - loss: 4.1690e-04
# Epoch 10/10
# 3571/3571 [==============================] - 38s 11ms/step - loss: 4.2119e-04

# %%
# Get the models predicted price values

predictions = model.predict(x_test)
print(predictions.shape)

predictions=np.reshape(predictions,(predictions.shape[0], predictions.shape[1]))
#print(x_test.shape)

# un-scaling 
predictions = scaler.inverse_transform(predictions)
# Out:
# 29/29 [==============================] - 0s 6ms/step
# (907, 1)

# %%
#Get the root mean squared error (RMSE) 
rmse= np.sqrt( np.mean((predictions - y_test)**2))
print('Root Mean Square Error',rmse)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score


# Calculate test metrics
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, predictions)

r2 = r2_score(y_test, predictions)
evs = explained_variance_score(y_test, predictions)

mape = np.mean(np.abs((y_test - predictions) / y_test)) * 100
mpe = np.mean((y_test - predictions) / y_test) * 100

print(f"Mean Squared Error (MSE): {mse}")
print(f"Root-Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R2 Score: {r2}")
print(f"Explained Variance Score: {evs}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}")
print(f"Mean Percentage Error (MPE): {mpe}")
# Out:
# Root Mean Square Error 0.28988927882454124
# Mean Squared Error (MSE): 0.08403579397741262
# Root-Mean Squared Error (RMSE): 0.28988927882454124
# Mean Absolute Error (MAE): 0.24681113799325424
# R2 Score: 0.9008416538729836
# Explained Variance Score: 0.9571830252911349
# Mean Absolute Percentage Error (MAPE): 4.635891655610141
# Mean Percentage Error (MPE): -4.250743201544184

# %%
plt.plot(predictions)
plt.plot(y_test)

# %%
#plot the data

train=data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions']=predictions

plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train','Test', 'Predictions'], loc = 'lower right')

# %%
error=((y_test-predictions)**2)
plt.plot(error)

print(np.sqrt(np.sum(error)/len(error)))
# Out:
# 0.5214837352622248

# %%
keras.utils.plot_model(model, "model.png", show_shapes=True)

#keras.utils.plot_model(model1, "Model1.png", show_shapes=True)
#keras.utils.plot_model(model2, "Model2.png", show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18752\3939047814.py in <module>
# ----> 1 keras.utils.plot_model(model, "model.png", show_shapes=True)
#       2
#       3 #keras.utils.plot_model(model1, "Model1.png", show_shapes=True)
#       4 #keras.utils.plot_model(model2, "Model2.png", show_shapes=True)
#
# NameError: name 'keras' is not defined

# %% [markdown]
# # Model and session save

# %%
import dill                            #pip install dill --user
import keras

# Calling `save('my_model.keras')` creates a zip archive `my_model.keras`.
model.save("LSTMTransDense_SCI_42.keras")

filename = 'globalsave_LSTMTransDense_SCI_42.pkl'
dill.dump_session(filename)



# It can be used to reconstruct the model identically.
#reconstructed_model = keras.models.load_model("LSTM_model.keras")
#model = keras.models.load_model('LSTM_model.keras')
# Let's check:
#np.testing.assert_allclose(
#    model.predict(test_input), reconstructed_model.predict(test_input)
#)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18752\88379968.py in <module>
#       6
#       7 filename = 'globalsave_LSTMTransDense_SCI_42.pkl'
# ----> 8 dill.dump_session(filename)
#       9
#      10
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in dump_session(filename, main, byref, **kwds)
#     401         pickler._recurse = False # disable pickling recursion for globals
#     402         pickler._session = True  # is best indicator of when pickling a session
# --> 403         pickler.dump(main)
#     404     finally:
#     405         if f is not filename:  # If newly opened file
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in dump(self, obj)
#     496             raise PicklingError(msg)
#     497         else:
# --> 498             StockPickler.dump(self, obj)
#     499         stack.clear()  # clear record of 'recursion-sensitive' pickled objects
#     500         return
#
# ~\anaconda3\lib\pickle.py in dump(self, obj)
#     485         if self.proto >= 4:
#     486             self.framer.start_framing()
# --> 487         self.save(obj)
#     488         self.write(STOP)
#     489         self.framer.end_framing()
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module(pickler, obj)
#    1373             [_main_dict.pop(item, None) for item in singletontypes
#    1374                 + ["__builtins__", "__loader__"]]
# -> 1375             pickler.save_reduce(_import_module, (obj.__name__,), obj=obj,
#    1376                                 state=_main_dict)
#    1377             log.info("# M1")
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     686             args = args[1:]
#     687             save(cls)
# --> 688             save(args)
#     689             write(NEWOBJ)
#     690         else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\pickle.py in save_tuple(self, obj)
#     884         if n <= 3 and self.proto >= 2:
#     885             for element in obj:
# --> 886                 save(element)
#     887             # Subtle.  Same as in the big comment below.
#     888             if id(obj) in memo:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\pickle.py in save_list(self, obj)
#     929
#     930         self.memoize(obj)
# --> 931         self._batch_appends(obj)
#     932
#     933     dispatch[list] = save_list
#
# ~\anaconda3\lib\pickle.py in _batch_appends(self, items)
#     956                 write(APPENDS)
#     957             elif n:
# --> 958                 save(tmp[0])
#     959                 write(APPEND)
#     960             # else tmp is empty, and we're done
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\pickle.py in save_list(self, obj)
#     929
#     930         self.memoize(obj)
# --> 931         self._batch_appends(obj)
#     932
#     933     dispatch[list] = save_list
#
# ~\anaconda3\lib\pickle.py in _batch_appends(self, items)
#     956                 write(APPENDS)
#     957             elif n:
# --> 958                 save(tmp[0])
#     959                 write(APPEND)
#     960             # else tmp is empty, and we're done
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\pickle.py in save_list(self, obj)
#     929
#     930         self.memoize(obj)
# --> 931         self._batch_appends(obj)
#     932
#     933     dispatch[list] = save_list
#
# ~\anaconda3\lib\pickle.py in _batch_appends(self, items)
#     956                 write(APPENDS)
#     957             elif n:
# --> 958                 save(tmp[0])
#     959                 write(APPEND)
#     960             # else tmp is empty, and we're done
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\pickle.py in save_list(self, obj)
#     929
#     930         self.memoize(obj)
# --> 931         self._batch_appends(obj)
#     932
#     933     dispatch[list] = save_list
#
# ~\anaconda3\lib\pickle.py in _batch_appends(self, items)
#     956                 write(APPENDS)
#     957             elif n:
# --> 958                 save(tmp[0])
#     959                 write(APPEND)
#     960             # else tmp is empty, and we're done
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\pickle.py in save_list(self, obj)
#     929
#     930         self.memoize(obj)
# --> 931         self._batch_appends(obj)
#     932
#     933     dispatch[list] = save_list
#
# ~\anaconda3\lib\pickle.py in _batch_appends(self, items)
#     953                 write(MARK)
#     954                 for x in tmp:
# --> 955                     save(x)
#     956                 write(APPENDS)
#     957             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\pickle.py in save_list(self, obj)
#     929
#     930         self.memoize(obj)
# --> 931         self._batch_appends(obj)
#     932
#     933     dispatch[list] = save_list
#
# ~\anaconda3\lib\pickle.py in _batch_appends(self, items)
#     953                 write(MARK)
#     954                 for x in tmp:
# --> 955                     save(x)
#     956                 write(APPENDS)
#     957             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\pickle.py in save_list(self, obj)
#     929
#     930         self.memoize(obj)
# --> 931         self._batch_appends(obj)
#     932
#     933     dispatch[list] = save_list
#
# ~\anaconda3\lib\pickle.py in _batch_appends(self, items)
#     956                 write(APPENDS)
#     957             elif n:
# --> 958                 save(tmp[0])
#     959                 write(APPEND)
#     960             # else tmp is empty, and we're done
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\pickle.py in save_list(self, obj)
#     929
#     930         self.memoize(obj)
# --> 931         self._batch_appends(obj)
#     932
#     933     dispatch[list] = save_list
#
# ~\anaconda3\lib\pickle.py in _batch_appends(self, items)
#     956                 write(APPENDS)
#     957             elif n:
# --> 958                 save(tmp[0])
#     959                 write(APPEND)
#     960             # else tmp is empty, and we're done
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_function(pickler, obj)
#    1491             if _memo: pickler._recurse = False
#    1492             fkwdefaults = getattr(obj, '__kwdefaults__', None)
# -> 1493             pickler.save_reduce(_create_function, (obj.__code__,
#    1494                                 globs, obj.__name__,
#    1495                                 obj.__defaults__, obj.__closure__,
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     690         else:
#     691             save(func)
# --> 692             save(args)
#     693             write(REDUCE)
#     694
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\pickle.py in save_tuple(self, obj)
#     899         write(MARK)
#     900         for element in obj:
# --> 901             save(element)
#     902
#     903         if id(obj) in memo:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# ~\anaconda3\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     988             # we only care about session the first pass thru
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#     992     return
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     576                 reduce = getattr(obj, "__reduce_ex__", None)
#     577                 if reduce is not None:
# --> 578                     rv = reduce(self.proto)
#     579                 else:
#     580                     reduce = getattr(obj, "__reduce__", None)
#
# TypeError: cannot pickle 'tensorflow.python.framework._pywrap_python_api_dispatcher.PythonAPIDispatcher' object

# %%
## Saving as pickle file


import pickle

# save the iris classification model as a pickle file
model_pkl_file = "LSTMTransDense_SCI_42.pkl"  

with open(model_pkl_file, 'wb') as file:  
    pickle.dump(model, file)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, query_layer_call_fn while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://534c694b-04cb-4031-83b2-4e32357eb750/assets
# INFO:tensorflow:Assets written to: ram://534c694b-04cb-4031-83b2-4e32357eb750/assets

# %% [markdown]
# # Saved Model Load from Disk

# %%
# load model from keras file


import numpy as np
import keras
import dill                            #pip install dill --user


#filename = 'globalsave_LSTM.pkl'

#dill.load_session(filename)

reconstructed_model = keras.models.load_model("LSTMTransDense_SCI_42.keras")

# Let's check:
np.testing.assert_allclose(
    reconstructed_model.predict(x_test), reconstructed_model.predict(x_test)
)
# Out:
# 137/137 [==============================] - 1s 5ms/step
# 137/137 [==============================] - 1s 5ms/step

# %%
import pickle

model_pkl_file = "LSTMTransDense_SCI_42.pkl" 

with open(model_pkl_file, 'rb') as file:  
    reconstructed_model = pickle.load(file)


        
# evaluate model 
y_predict = reconstructed_model.predict(x_test)

# check results
#print(classification_report(y_test, y_predict))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18752\3127588499.py in <module>
#       4
#       5 with open(model_pkl_file, 'rb') as file:
# ----> 6     reconstructed_model = pickle.load(file)
#       7
#       8
#
# ~\anaconda3\lib\site-packages\keras\saving\pickle_utils.py in deserialize_model_from_bytecode(serialized_model)
#      45                 with tf.io.gfile.GFile(dest_path, "wb") as f:
#      46                     f.write(archive.extractfile(name).read())
# ---> 47     model = save_module.load_model(temp_dir)
#      48     tf.io.gfile.rmtree(temp_dir)
#      49     return model
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\saved_model\load.py in load_partial(export_dir, filters, tags, options)
#     931                         ckpt_options, options, filters)
#     932       except errors.NotFoundError as err:
# --> 933         raise FileNotFoundError(
#     934             str(err) + "\n You may be trying to load on a different device "
#     935             "from the computational device. Consider setting the "
#
# FileNotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for ram://f5d5792a-bddb-4c00-8e72-ce202f246a8b/variables/variables
#  You may be trying to load on a different device from the computational device. Consider setting the `experimental_io_device` option in `tf.saved_model.LoadOptions` to the io_device such as '/job:localhost'.

# %%
reconstructed_model.summary()



predictions = reconstructed_model.predict(x_test)
print(predictions.shape)

predictions=np.reshape(predictions,(predictions.shape[0], predictions.shape[1]))
#print(x_test.shape)

# un-scaling 
predictions = scaler.inverse_transform(predictions)


rmse= np.sqrt( np.mean((predictions - y_test)**2))
print('Root Mean Square Error',rmse)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 60, 1)]      0           []
#
#  lstm (LSTM)                    (None, 60, 30)       3840        ['input_1[0][0]']
#
#  lstm_1 (LSTM)                  (None, 20)           4080        ['lstm[0][0]']
#
#  reshape (Reshape)              (None, 20, 1)        0           ['lstm_1[0][0]']
#
#  dropout (Dropout)              (None, 20, 1)        0           ['reshape[0][0]']
#
#  layer_normalization (LayerNorm  (None, 20, 1)       2           ['dropout[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 20, 1)       421         ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 20, 1)        0           ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 20, 1)       0           ['dropout_1[0][0]',
#  da)                                                              'dropout[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 20, 1)       2           ['tf.__operators__.add[0][0]']
#  rmalization)
#
#  dense (Dense)                  (None, 20, 4)        8           ['layer_normalization_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 20, 4)        0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 20, 1)        5           ['dropout_2[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 20, 1)       0           ['dense_1[0][0]',
#  mbda)                                                            'tf.__operators__.add[0][0]']
#
#  global_average_pooling1d (Glob  (None, 20)          0           ['tf.__operators__.add_1[0][0]']
#  alAveragePooling1D)
#
#  dropout_3 (Dropout)            (None, 20)           0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_2 (Dense)                (None, 30)           630         ['dropout_3[0][0]']
#
#  dense_3 (Dense)                (None, 1)            31          ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 9,019
# Trainable params: 9,019
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 137/137 [==============================] - 1s 5ms/step
# (4355, 1)
# Root Mean Square Error Close    90.714711
# dtype: float64

# %%
#plot the data

train=data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions']=predictions

plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train','Val', 'Predictions'], loc = 'lower right')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18752\2892090635.py in <module>
#       3 train=data[:training_data_len]
#       4 valid = data[training_data_len:]
# ----> 5 valid['Predictions']=predictions
#       6
#       7 plt.figure(figsize=(16,8))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3830         ensure homogeneity.
#    3831         """
# -> 3832         value = self._sanitize_column(value)
#    3833
#    3834         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4536
#    4537         if is_list_like(value):
# -> 4538             com.require_length_match(value, self.index)
#    4539         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4540
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     555     """
#     556     if len(data) != len(index):
# --> 557         raise ValueError(
#     558             "Length of values "
#     559             f"({len(data)}) "
#
# ValueError: Length of values (4355) does not match length of index (1612)

# %%
#reconstructed_model = keras.models.load_model(
#    "LSTM_model.keras",
#    custom_objects={"CustomLayer": CustomLayer, "custom_fn": custom_fn},
#)

# %% [markdown]
# # Test Dataset!

# %%
##############################  TEST #######################


data_new=dataT[3674:]
print(data_new.shape)

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data_new=scaler.fit_transform(data_new)
#y_test= dataset [training_data_len:, :]
test_data_new=scaled_data_new
print(scaled_data_new)


x_test=[]
y_test= data_new[60:]


for i in range (60, len(test_data_new)):
    x_test.append(test_data_new[i-60:i,0])

x_test= np.array(x_test)

print(x_test.shape)

x_test=np.reshape(x_test,(x_test.shape[0], x_test.shape[1],1))

    

#print(x_test)
#print(y_test)
# Out:
# (4415, 1)
# [[0.        ]
#  [0.00085406]
#  [0.00177861]
#  ...
#  [0.33476952]
#  [0.34286894]
#  [0.35016064]]
# (4355, 60)

# %%
predictions = reconstructed_model.predict(x_test)
print(predictions.shape)

predictions=np.reshape(predictions,(predictions.shape[0], predictions.shape[1]))
#print(x_test.shape)

# un-scaling 
predictions = scaler.inverse_transform(predictions)
# Out:
# 137/137 [==============================] - 1s 5ms/step
# (4355, 1)

# %%
#Get the root mean squared error (RMSE) 

rmse= np.sqrt( np.mean((predictions - y_test)**2))
rmse


from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score


# Calculate test metrics
mse = mean_squared_error(y_test.values, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test.values, predictions)

r2 = r2_score(y_test.values, predictions)
evs = explained_variance_score(y_test.values, predictions)

mape = np.mean(np.abs((y_test.values, predictions) / y_test.values)) * 100
mpe = np.mean((y_test.values, predictions) / y_test.values) * 100

print(f"Mean Squared Error (MSE): {mse}")
print(f"Root-Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R2 Score: {r2}")
print(f"Explained Variance Score: {evs}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}")
print(f"Mean Percentage Error (MPE): {mpe}")
# Out:
# Mean Squared Error (MSE): 8229.15877496496
# Root-Mean Squared Error (RMSE): 90.71471090713436
# Mean Absolute Error (MAE): 71.74078110424439
# R2 Score: 0.983287971932333
# Explained Variance Score: 0.9912581548544676
# Mean Absolute Percentage Error (MAPE): 101.29260654512046
# Mean Percentage Error (MPE): 101.29260654512046

# %%
#train=data[:training_data_len]
#valid = data[training_data_len:]
#valid['Predictions']=predictions

plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(y_test.values)
plt.plot(predictions)

#plt.plot(train['Close'])
#plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Test', 'Predictions'], loc = 'lower right')

# %%
error=((y_test-predictions)**2)
plt.plot(error)

#rmse= np.sqrt(np.sum(error)/len(error))
#print(rmse)

# %%
import keras

keras.utils.plot_model(model, "ensemble_model.png", show_shapes=True)

# %%
# !pip install visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting visualkeras
#   Downloading visualkeras-0.1.3-py3-none-any.whl (16 kB)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.18.post0-cp39-cp39-win_amd64.whl (44 kB)
#      -------------------------------------- 45.0/45.0 kB 445.0 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.1 in c:\users\dipayan\anaconda3\lib\site-packages (from visualkeras) (1.24.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dipayan\anaconda3\lib\site-packages (from visualkeras) (9.2.0)
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18.post0 visualkeras-0.1.3
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\dipayan\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\dipayan\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\dipayan\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\dipayan\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\dipayan\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\dipayan\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dipayan\anaconda3\lib\site-packages)

# %%
import visualkeras

#model = ...

visualkeras.layered_view(model).show() # display using your system viewer
visualkeras.layered_view(model, to_file='output.png') # write to disk
visualkeras.layered_view(model, to_file='output.png').show() # write and show

visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=594x200>

# %%
import torch
from torchviz import make_dot

# create some sample input data
x = torch.randn(1, 3, 256, 256)

# generate predictions for the sample data
y = MyPyTorchModel()(x)

# generate a model architecture visualization
make_dot(y.mean(),
         params=dict(MyPyTorchModel().named_parameters()),
         show_attrs=True,
         show_saved=True).render("MyPyTorchModel_torchviz", format="png")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18612\1844221176.py in <module>
#       1 import torch
# ----> 2 from torchviz import make_dot
#       3
#       4 # create some sample input data
#       5 x = torch.randn(1, 3, 256, 256)
#
# ModuleNotFoundError: No module named 'torchviz'

# %%
# !pip install neutron
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting neutron
#   Downloading neutron-24.0.1-py3-none-any.whl (4.3 MB)
#      ---------------------------------------- 4.3/4.3 MB 626.1 kB/s eta 0:00:00
# Collecting netaddr>=0.7.18
#   Downloading netaddr-1.3.0-py3-none-any.whl (2.3 MB)
#      ---------------------------------------- 2.3/2.3 MB 655.0 kB/s eta 0:00:00
# Collecting oslo.config>=9.0.0
#   Downloading oslo.config-9.6.0-py3-none-any.whl (132 kB)
#      -------------------------------------- 132.1/132.1 kB 1.3 MB/s eta 0:00:00
# Collecting python-neutronclient>=7.8.0
#   Downloading python_neutronclient-11.3.1-py3-none-any.whl (295 kB)
#      -------------------------------------- 295.5/295.5 kB 1.3 MB/s eta 0:00:00
# Collecting Paste>=2.0.2
#   Downloading Paste-3.10.1-py3-none-any.whl (289 kB)
#      -------------------------------------- 289.3/289.3 kB 1.3 MB/s eta 0:00:00
# Collecting oslo.cache>=1.26.0
#   Downloading oslo.cache-3.8.0-py3-none-any.whl (75 kB)
#      ---------------------------------------- 75.8/75.8 kB 4.4 MB/s eta 0:00:00
# Collecting oslo.utils>=7.0.0
#   Downloading oslo.utils-7.3.0-py3-none-any.whl (129 kB)
#      ---------------------------------------- 129.5/129.5 kB ? eta 0:00:00
# Collecting oslo.upgradecheck>=1.3.0
#   Downloading oslo.upgradecheck-2.4.0-py3-none-any.whl (14 kB)
# Collecting oslo.rootwrap>=5.15.0
#   Downloading oslo.rootwrap-7.3.0-py3-none-any.whl (38 kB)
# Collecting ovs>=2.10.0
#   Downloading ovs-3.4.0.tar.gz (132 kB)
#      -------------------------------------- 132.1/132.1 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting os-vif>=3.1.0
#   Downloading os_vif-3.6.0-py3-none-any.whl (112 kB)
#      -------------------------------------- 112.9/112.9 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=6.0.0 in c:\users\dipayan\anaconda3\lib\site-packages (from neutron) (8.0.1)
# Collecting pbr>=4.0.0
#   Downloading pbr-6.0.0-py2.py3-none-any.whl (107 kB)
#      ------------------------------------ 107.5/107.5 kB 568.8 kB/s eta 0:00:00
# Requirement already satisfied: decorator>=4.1.0 in c:\users\dipayan\anaconda3\lib\site-packages (from neutron) (5.1.1)
# Collecting python-designateclient>=2.7.0
#   Downloading python_designateclient-6.0.1-py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.4/95.4 kB 5.7 MB/s eta 0:00:00
# Collecting oslo.versionedobjects>=1.35.1
#   Downloading oslo.versionedobjects-3.4.0-py3-none-any.whl (86 kB)
#      ---------------------------------------- 86.5/86.5 kB 4.8 MB/s eta 0:00:00
# Collecting debtcollector>=1.19.0
#   Downloading debtcollector-3.0.0-py3-none-any.whl (23 kB)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-5.3.0-py3-none-any.whl (49 kB)
#      ---------------------------------------- 49.7/49.7 kB ? eta 0:00:00
# Requirement already satisfied: requests>=2.18.0 in c:\users\dipayan\anaconda3\lib\site-packages (from neutron) (2.31.0)
# Collecting oslo.service>=2.8.0
#   Downloading oslo.service-3.5.0-py3-none-any.whl (77 kB)
#      ---------------------------------------- 77.7/77.7 kB 4.5 MB/s eta 0:00:00
# Collecting ovsdbapp>=2.3.0
#   Downloading ovsdbapp-2.8.0-py3-none-any.whl (142 kB)
#      -------------------------------------- 142.9/142.9 kB 8.8 MB/s eta 0:00:00
# Collecting oslo.policy>=3.12.0
#   Downloading oslo.policy-4.4.0-py3-none-any.whl (88 kB)
#      ---------------------------------------- 88.7/88.7 kB ? eta 0:00:00
# Collecting openstacksdk>=0.31.2
#   Downloading openstacksdk-3.3.0-py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 564.7 kB/s eta 0:00:00
# Collecting oslo.middleware>=3.31.0
#   Downloading oslo.middleware-6.2.0-py3-none-any.whl (64 kB)
#      -------------------------------------- 64.7/64.7 kB 499.7 kB/s eta 0:00:00
# Collecting oslo.privsep>=2.3.0
#   Downloading oslo.privsep-3.4.0-py3-none-any.whl (38 kB)
# Collecting keystonemiddleware>=5.1.0
#   Downloading keystonemiddleware-10.7.0-py3-none-any.whl (150 kB)
#      -------------------------------------- 150.7/150.7 kB 9.4 MB/s eta 0:00:00
# Collecting oslo.reports>=1.18.0
#   Downloading oslo.reports-3.4.0-py3-none-any.whl (53 kB)
#      ---------------------------------------- 53.3/53.3 kB ? eta 0:00:00
# Requirement already satisfied: SQLAlchemy>=1.4.23 in c:\users\dipayan\anaconda3\lib\site-packages (from neutron) (1.4.39)
# Collecting os-resource-classes>=1.1.0
#   Downloading os_resource_classes-1.1.0-py3-none-any.whl (11 kB)
# Collecting oslo.messaging>=7.0.0
#   Downloading oslo.messaging-14.8.1-py3-none-any.whl (259 kB)
#      -------------------------------------- 259.8/259.8 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2>=2.10 in c:\users\dipayan\anaconda3\lib\site-packages (from neutron) (2.11.3)
# Collecting oslo.serialization>=2.25.0
#   Downloading oslo.serialization-5.5.0-py3-none-any.whl (26 kB)
# Collecting os-ken>=2.2.0
#   Downloading os_ken-2.10.0-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 631.5 kB/s eta 0:00:00
# Collecting osprofiler>=2.3.0
#   Downloading osprofiler-4.1.0-py3-none-any.whl (95 kB)
#      -------------------------------------- 95.4/95.4 kB 773.9 kB/s eta 0:00:00
# Collecting oslo.context>=2.22.0
#   Downloading oslo.context-5.6.0-py3-none-any.whl (20 kB)
# Collecting oslo.db>=4.44.0
#   Downloading oslo.db-16.0.0-py3-none-any.whl (153 kB)
#      -------------------------------------- 153.3/153.3 kB 8.9 MB/s eta 0:00:00
# Collecting keystoneauth1>=3.14.0
#   Downloading keystoneauth1-5.7.0-py3-none-any.whl (324 kB)
#      -------------------------------------- 324.3/324.3 kB 1.2 MB/s eta 0:00:00
# Collecting PasteDeploy>=1.5.0
#   Downloading PasteDeploy-3.1.0-py3-none-any.whl (16 kB)
# Collecting oslo.log>=5.3.0
#   Downloading oslo.log-6.1.2-py3-none-any.whl (74 kB)
#      ---------------------------------------- 74.2/74.2 kB ? eta 0:00:00
# Collecting oslo.i18n>=3.20.0
#   Downloading oslo.i18n-6.4.0-py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.8/46.8 kB ? eta 0:00:00
# Requirement already satisfied: pyOpenSSL>=17.1.0 in c:\users\dipayan\anaconda3\lib\site-packages (from neutron) (22.0.0)
# Collecting tooz>=1.58.0
#   Downloading tooz-6.2.0-py3-none-any.whl (91 kB)
#      ---------------------------------------- 91.3/91.3 kB ? eta 0:00:00
# Collecting alembic>=1.6.5
#   Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#      -------------------------------------- 233.0/233.0 kB 1.8 MB/s eta 0:00:00
# Collecting eventlet>=0.26.1
#   Downloading eventlet-0.36.1-py3-none-any.whl (360 kB)
#      -------------------------------------- 360.5/360.5 kB 1.1 MB/s eta 0:00:00
# Collecting neutron-lib>=3.9.0
#   Downloading neutron_lib-3.14.1-py3-none-any.whl (609 kB)
#      ------------------------------------ 609.8/609.8 kB 816.8 kB/s eta 0:00:00
# Collecting oslo.concurrency>=3.26.0
#   Downloading oslo.concurrency-6.1.0-py3-none-any.whl (48 kB)
#      ---------------------------------------- 48.5/48.5 kB 2.5 MB/s eta 0:00:00
# Collecting httplib2>=0.9.1
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.9/96.9 kB ? eta 0:00:00
# Collecting Routes>=2.3.1
#   Downloading Routes-2.5.1-py2.py3-none-any.whl (40 kB)
#      ---------------------------------------- 40.1/40.1 kB ? eta 0:00:00
# Collecting futurist>=1.2.0
#   Downloading futurist-3.0.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: psutil>=5.3.0 in c:\users\dipayan\anaconda3\lib\site-packages (from neutron) (5.9.0)
# Collecting python-novaclient>=9.1.0
#   Downloading python_novaclient-18.6.0-py3-none-any.whl (335 kB)
#      -------------------------------------- 336.0/336.0 kB 1.2 MB/s eta 0:00:00
# Collecting netifaces>=0.10.4
#   Downloading netifaces-0.11.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pecan>=1.4.0
#   Downloading pecan-1.5.1-py3-none-any.whl (146 kB)
#      -------------------------------------- 146.1/146.1 kB 9.1 MB/s eta 0:00:00
# Collecting WebOb>=1.8.2
#   Downloading WebOb-1.8.8-py2.py3-none-any.whl (115 kB)
#      -------------------------------------- 115.3/115.3 kB 6.6 MB/s eta 0:00:00
# Collecting wmi>=1.4.9
#   Downloading WMI-1.5.1-py2.py3-none-any.whl (28 kB)
# Collecting Mako
#   Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.6/78.6 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in c:\users\dipayan\anaconda3\lib\site-packages (from alembic>=1.6.5->neutron) (4.12.2)
# Requirement already satisfied: wrapt>=1.7.0 in c:\users\dipayan\anaconda3\lib\site-packages (from debtcollector>=1.19.0->neutron) (1.14.1)
# Requirement already satisfied: greenlet>=1.0 in c:\users\dipayan\anaconda3\lib\site-packages (from eventlet>=0.26.1->neutron) (1.1.1)
# Requirement already satisfied: dnspython>=1.15.0 in c:\users\dipayan\anaconda3\lib\site-packages (from eventlet>=0.26.1->neutron) (2.6.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\dipayan\anaconda3\lib\site-packages (from httplib2>=0.9.1->neutron) (3.0.9)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\dipayan\anaconda3\lib\site-packages (from Jinja2>=2.10->neutron) (2.0.1)
# Collecting iso8601>=0.1.11
#   Downloading iso8601-2.1.0-py3-none-any.whl (7.5 kB)
# Collecting os-service-types>=1.2.0
#   Downloading os_service_types-1.7.0-py2.py3-none-any.whl (24 kB)
# Collecting pycadf!=2.0.0,>=1.1.0
#   Downloading pycadf-3.1.1-py3-none-any.whl (39 kB)
# Collecting python-keystoneclient>=3.20.0
#   Downloading python_keystoneclient-5.4.0-py3-none-any.whl (397 kB)
#      ------------------------------------ 397.2/397.2 kB 992.2 kB/s eta 0:00:00
# Requirement already satisfied: PyJWT>=2.4.0 in c:\users\dipayan\anaconda3\lib\site-packages (from keystonemiddleware>=5.1.0->neutron) (2.4.0)
# Collecting setproctitle>=1.1.10
#   Downloading setproctitle-1.3.3-cp39-cp39-win_amd64.whl (11 kB)
# Collecting os-traits>=0.9.0
#   Downloading os_traits-3.1.0-py3-none-any.whl (41 kB)
#      ---------------------------------------- 41.3/41.3 kB 1.9 MB/s eta 0:00:00
# Collecting platformdirs>=3
#   Downloading platformdirs-4.2.2-py3-none-any.whl (18 kB)
# Collecting dogpile.cache>=0.6.5
#   Downloading dogpile.cache-1.3.3-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.7/58.7 kB ? eta 0:00:00
# Requirement already satisfied: PyYAML>=3.13 in c:\users\dipayan\anaconda3\lib\site-packages (from openstacksdk>=0.31.2->neutron) (6.0)
# Requirement already satisfied: cryptography>=2.7 in c:\users\dipayan\anaconda3\lib\site-packages (from openstacksdk>=0.31.2->neutron) (37.0.1)
# Requirement already satisfied: jsonpatch!=1.20,>=1.16 in c:\users\dipayan\anaconda3\lib\site-packages (from openstacksdk>=0.31.2->neutron) (1.32)
# Requirement already satisfied: jmespath>=0.9.0 in c:\users\dipayan\anaconda3\lib\site-packages (from openstacksdk>=0.31.2->neutron) (0.10.0)
# Requirement already satisfied: requestsexceptions>=1.2.0 in c:\users\dipayan\anaconda3\lib\site-packages (from openstacksdk>=0.31.2->neutron) (1.4.0)
# Requirement already satisfied: msgpack>=1.0.0 in c:\users\dipayan\anaconda3\lib\site-packages (from os-ken>=2.2.0->neutron) (1.0.3)
# Collecting ncclient>=0.6.13
#   Downloading ncclient-0.6.15.tar.gz (634 kB)
#      ------------------------------------ 634.9/634.9 kB 784.7 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: packaging>=20.4 in c:\users\dipayan\anaconda3\lib\site-packages (from os-ken>=2.2.0->neutron) (21.3)
# Collecting fasteners>=0.7.0
#   Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Collecting rfc3986>=1.2.0
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting testresources>=2.0.0
#   Downloading testresources-2.0.1-py2.py3-none-any.whl (36 kB)
# Collecting testscenarios>=0.4
#   Downloading testscenarios-0.5.0-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\dipayan\anaconda3\lib\site-packages (from oslo.log>=5.3.0->neutron) (2.8.2)
# Collecting oslo.metrics>=0.2.1
#   Downloading oslo.metrics-0.9.0-py3-none-any.whl (13 kB)
# Collecting kombu>=4.6.6
#   Downloading kombu-5.4.0-py3-none-any.whl (200 kB)
#      -------------------------------------- 200.9/200.9 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: cachetools>=2.0.0 in c:\users\dipayan\appdata\roaming\python\python39\site-packages (from oslo.messaging>=7.0.0->neutron) (5.3.0)
# Collecting amqp>=2.5.2
#   Downloading amqp-5.2.0-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.9/50.9 kB ? eta 0:00:00
# Requirement already satisfied: bcrypt>=3.1.3 in c:\users\dipayan\anaconda3\lib\site-packages (from oslo.middleware>=3.31.0->neutron) (3.2.0)
# Requirement already satisfied: statsd>=3.2.1 in c:\users\dipayan\anaconda3\lib\site-packages (from oslo.middleware>=3.31.0->neutron) (4.0.1)
# Requirement already satisfied: cffi>=1.14.0 in c:\users\dipayan\anaconda3\lib\site-packages (from oslo.privsep>=2.3.0->neutron) (1.15.1)
# Collecting tzdata>=2022.4
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      -------------------------------------- 345.4/345.4 kB 1.1 MB/s eta 0:00:00
# Collecting Yappi>=1.0
#   Downloading yappi-1.6.0-cp39-cp39-win_amd64.whl (34 kB)
# Collecting PrettyTable>=0.7.1
#   Downloading prettytable-3.11.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: sortedcontainers in c:\users\dipayan\anaconda3\lib\site-packages (from ovs>=2.10.0->neutron) (2.4.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\dipayan\anaconda3\lib\site-packages (from ovs>=2.10.0->neutron) (302)
# Collecting fixtures>=3.0.0
#   Downloading fixtures-4.1.0-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.5/64.5 kB ? eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\dipayan\anaconda3\lib\site-packages (from Paste>=2.0.2->neutron) (63.4.1)
# Collecting logutils>=0.3
#   Downloading logutils-0.3.5.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cliff!=2.9.0,>=2.8.0
#   Downloading cliff-4.7.0-py3-none-any.whl (81 kB)
#      ---------------------------------------- 81.2/81.2 kB ? eta 0:00:00
# Requirement already satisfied: jsonschema>=3.2.0 in c:\users\dipayan\anaconda3\lib\site-packages (from python-designateclient>=2.7.0->neutron) (4.16.0)
# Collecting osc-lib>=1.8.0
#   Downloading osc_lib-3.1.0-py3-none-any.whl (89 kB)
#      ---------------------------------------- 89.6/89.6 kB 5.0 MB/s eta 0:00:00
# Collecting os-client-config>=1.28.0
#   Downloading os_client_config-2.1.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dipayan\anaconda3\lib\site-packages (from requests>=2.18.0->neutron) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dipayan\anaconda3\lib\site-packages (from requests>=2.18.0->neutron) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dipayan\anaconda3\lib\site-packages (from requests>=2.18.0->neutron) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dipayan\anaconda3\lib\site-packages (from requests>=2.18.0->neutron) (2.0.4)
# Requirement already satisfied: six in c:\users\dipayan\anaconda3\lib\site-packages (from Routes>=2.3.1->neutron) (1.16.0)
# Requirement already satisfied: repoze.lru>=0.3 in c:\users\dipayan\anaconda3\lib\site-packages (from Routes>=2.3.1->neutron) (0.7)
# Collecting voluptuous>=0.8.9
#   Downloading voluptuous-0.15.2-py3-none-any.whl (31 kB)
# Collecting vine<6.0.0,>=5.0.0
#   Downloading vine-5.1.0-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pycparser in c:\users\dipayan\anaconda3\lib\site-packages (from cffi>=1.14.0->oslo.privsep>=2.3.0->neutron) (2.21)
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.3-py3-none-any.whl (147 kB)
#      -------------------------------------- 147.2/147.2 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\dipayan\anaconda3\lib\site-packages (from cliff!=2.9.0,>=2.8.0->python-designateclient>=2.7.0->neutron) (4.11.3)
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.2-py3-none-any.whl (30 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dipayan\anaconda3\lib\site-packages (from jsonpatch!=1.20,>=1.16->openstacksdk>=0.31.2->neutron) (2.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\dipayan\anaconda3\lib\site-packages (from jsonschema>=3.2.0->python-designateclient>=2.7.0->neutron) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\dipayan\anaconda3\lib\site-packages (from jsonschema>=3.2.0->python-designateclient>=2.7.0->neutron) (0.18.0)
# Requirement already satisfied: paramiko>=1.15.0 in c:\users\dipayan\anaconda3\lib\site-packages (from ncclient>=0.6.13->os-ken>=2.2.0->neutron) (2.8.1)
# Requirement already satisfied: lxml>=3.3.0 in c:\users\dipayan\anaconda3\lib\site-packages (from ncclient>=0.6.13->os-ken>=2.2.0->neutron) (4.9.1)
# Requirement already satisfied: prometheus-client>=0.6.0 in c:\users\dipayan\anaconda3\lib\site-packages (from oslo.metrics>=0.2.1->oslo.messaging>=7.0.0->neutron) (0.14.1)
# Requirement already satisfied: wcwidth in c:\users\dipayan\anaconda3\lib\site-packages (from PrettyTable>=0.7.1->oslo.upgradecheck>=1.3.0->neutron) (0.2.5)
# Requirement already satisfied: pytz>=2013.6 in c:\users\dipayan\anaconda3\lib\site-packages (from pycadf!=2.0.0,>=1.1.0->keystonemiddleware>=5.1.0->neutron) (2023.3.post1)
# Collecting testtools
#   Downloading testtools-2.7.2-py3-none-any.whl (179 kB)
#      -------------------------------------- 179.9/179.9 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: pyreadline3 in c:\users\dipayan\anaconda3\lib\site-packages (from cmd2>=1.0.0->cliff!=2.9.0,>=2.8.0->python-designateclient>=2.7.0->neutron) (3.4.1)
# Requirement already satisfied: pyperclip>=1.6 in c:\users\dipayan\anaconda3\lib\site-packages (from cmd2>=1.0.0->cliff!=2.9.0,>=2.8.0->python-designateclient>=2.7.0->neutron) (1.9.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\dipayan\anaconda3\lib\site-packages (from importlib-metadata>=4.4->cliff!=2.9.0,>=2.8.0->python-designateclient>=2.7.0->neutron) (3.8.0)
# Requirement already satisfied: pynacl>=1.0.1 in c:\users\dipayan\anaconda3\lib\site-packages (from paramiko>=1.15.0->ncclient>=0.6.13->os-ken>=2.2.0->neutron) (1.5.0)
# Building wheels for collected packages: netifaces, ovs, logutils, ncclient
#   Building wheel for netifaces (setup.py): started
#   Building wheel for netifaces (setup.py): finished with status 'error'
#   Running setup.py clean for netifaces
#   Building wheel for ovs (setup.py): started
#   Building wheel for ovs (setup.py): finished with status 'done'
#   Created wheel for ovs: filename=ovs-3.4.0-py3-none-any.whl size=152879 sha256=089f2f75fba0fb315eb7d766345e18605dad1a4a147d02316412cd4c3aaa154d
#   Stored in directory: C:\Users\dipayan\AppData\Local\Temp\pip-ephem-wheel-cache-tbtxh50q\wheels\a0\80\54\ec6c85cd58fe69dd572dd7d976190ad8c58ce18db39741a192
#   Building wheel for logutils (setup.py): started
#   Building wheel for logutils (setup.py): finished with status 'done'
#   Created wheel for logutils: filename=logutils-0.3.5-py3-none-any.whl size=19930 sha256=c6d47a5dce294bbf314dc84c197e97b22b8db3c1175d133175f1d887465fc926
#   Stored in directory: C:\Users\dipayan\AppData\Local\Temp\pip-ephem-wheel-cache-tbtxh50q\wheels\72\a7\97\a18ed864266911192f077c6cbb090639a8d1b9d3ad44da88d7
#   Building wheel for ncclient (setup.py): started
#   Building wheel for ncclient (setup.py): finished with status 'done'
#   Created wheel for ncclient: filename=ncclient-0.6.15-py2.py3-none-any.whl size=88094 sha256=f992dac93608a62d5bc195cf0c788211267b2d7624543f9ba22b6f1591f143bd
#   Stored in directory: C:\Users\dipayan\AppData\Local\Temp\pip-ephem-wheel-cache-tbtxh50q\wheels\fb\e5\bf\9076382d5c2948c3445ec8cacee704b7ee963fc327c17dbd20
# Successfully built ovs logutils ncclient
# Failed to build netifaces
# Installing collected packages: netifaces, logutils, Yappi, wmi, WebOb, voluptuous, vine, tzdata, testtools, setproctitle, Routes, rfc3986, PrettyTable, platformdirs, pbr, PasteDeploy, Paste, ovs, oslo.rootwrap, netaddr, Mako, iso8601, httplib2, futurist, fasteners, eventlet, debtcollector, cmd2, autopage, testscenarios, testresources, stevedore, pecan, oslo.i18n, oslo.context, os-traits, os-service-types, os-resource-classes, fixtures, amqp, alembic, ovsdbapp, oslo.utils, oslo.config, kombu, keystoneauth1, dogpile.cache, cliff, oslo.serialization, oslo.middleware, oslo.db, oslo.concurrency, openstacksdk, ncclient, tooz, python-novaclient, python-keystoneclient, pycadf, osprofiler, oslo.reports, oslo.policy, oslo.log, osc-lib, os-ken, os-client-config, python-neutronclient, python-designateclient, oslo.upgradecheck, oslo.service, oslo.privsep, oslo.metrics, oslo.cache, oslo.messaging, keystonemiddleware, oslo.versionedobjects, os-vif, neutron-lib, neutron
#   Running setup.py install for netifaces: started
#   Running setup.py install for netifaces: finished with status 'error'
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\dipayan\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\dipayan\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dipayan\anaconda3\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [7 lines of output]
#   C:\Users\dipayan\anaconda3\lib\site-packages\setuptools\config\setupcfg.py:463: SetuptoolsDeprecationWarning: The license_file parameter is deprecated, use license_files instead.
#     warnings.warn(msg, warning_class)
#   running bdist_wheel
#   running build
#   running build_ext
#   building 'netifaces' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for netifaces
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\dipayan\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dipayan\anaconda3\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   Running setup.py install for netifaces did not run successfully.
#   exit code: 1
#
#   [9 lines of output]
#   C:\Users\dipayan\anaconda3\lib\site-packages\setuptools\config\setupcfg.py:463: SetuptoolsDeprecationWarning: The license_file parameter is deprecated, use license_files instead.
#     warnings.warn(msg, warning_class)
#   running install
#   C:\Users\dipayan\anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   running build
#   running build_ext
#   building 'netifaces' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# netifaces
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\dipayan\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\dipayan\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\dipayan\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\dipayan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dipayan\anaconda3\lib\site-packages)

# %%
import neutron
neutron.start('LSTM_attention_model1.keras')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18612\1624651970.py in <module>
# ----> 1 import neutron
#       2 neutron.start('LSTM_attention_model1.keras')
#
# ModuleNotFoundError: No module named 'neutron'
